# %%
from neo_api_client import NeoAPI

# %%
def on_message(message):
    print('[Res]: ', message)


def on_error(message):
    result = message
    print('[OnError]: ', result)

# %%
client = NeoAPI(consumer_key="lRJ_tZfsnuJ_AlJQ9fG99d4PtV0a",
                               consumer_secret="x6gk6ijpaOV7eKHojBmbFdVj92Qa", environment='uat', on_message=on_message,
                               on_error=on_error)
# Out:
# {"data": {"access_token": "eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..gsS4KD13-_bn2JVZ_uEZ17Is6Mn8yGHY4aOnNRdCiyu1YcdXVnCbaLv558sxvDsT4F6rP5SrICOqqEX6nlKk2EPK0c-if8T4w0vlX7I8su46UK5ZnlTJC93lLbqmnstZhkhWDr00ATnXQKxJFLGB74-iRnxKCeiMlOorxzqueOCYaCngtOHnLhhRO47OJZ0NmBKfL0huoRZJvuPo77NtrEpRZdHBHr0wuCW5UbJGwvzR5WaV0svCSc-R8-ZOQesrN3DeHXtM70JBvgjptpev8IteiGc7er-qFdRtPPkw_wC2qNqkF6ZnytVpkqmwTMsb9Zpjmod5p4_6YD3CWe4fBw", "scope": "default", "token_type": "Bearer", "expires_in": 3600}}

# %%
client.login(mobilenumber="+919999999908", password="P@ssword1234")
# Out:
# {"data":{"otp":"3784","greetingName":"ABC08","mobile":"***********08","email":"ka***********@testyantra.com"}}
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..vQiKcYrmyIu_3sFswXk0-CIswxsLfWm4AKjrfe_7_RKgnl8hSTLEAsJbarbJrBiJTrwZ29NOm4kvVT5lOQrVxgeg2J8PSfosTMiaXiAvRKpsXoiv3HNNjXrtY29WKYx5Z9CM8q7hs-SaR_GUtEGAO_Y_2ArYTgr2WjeeoQ-RQ2WdjhRwYYKDulIAAQe_qqBmcltt_x3uDHiX50VzYDs_z6tNVLpQ87d0J9na9xv8ZJIOd7Gsdzowm7WYeFfPJ9r3pWPnGZn6MlB-XzQJNmGaY1gpFX2CdCmcfV0mOtnm3ievssTKnLLZEPFzT5TEL8zJUTjn9NE-kfPXMSHw9I2E1w',
#   'sid': '61c61dbb-6a71-4a6d-a36b-3a03fbd23220',
#   'rid': 'c3223557-4e0b-4c1e-a4cb-01c0ae4c2904',
#   'hsServerId': 'server1',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1682660961',
#    'lastUpdatedTS': '1683169993',
#    'multiplewatchlists': '1681368917',
#    'techchartpreferences': '1681796146'},
#   'ucc': 'ABCXYZ08',
#   'greetingName': 'ABC08',
#   'isTrialAccount': False,
#   'dataCenter': 'nm',
#   'searchAPIKey': 'FWOqAg9b8HofWde3k7wXgz0FTrAjKh9o'}}

# %%
client.session_2fa(OTP=input("ENTER OTP:- "))
# Out:
# ENTER OTP:- 3784
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..KdtWPw1lkNO6wXuN7MgvAKuBALA8coSDlNbiEdsirA5aJKS4SarNUtZ9759FerL1xTPlTNzi5lIOIpBuv1bbyNjXfOcGzWiq92kIQAZmO_j8u5L0Jsc2qan9Tv65Y17_R2Yzij9E_shTkEYRKji5jAbZ9w63dJUDO_M1dWS9uEjZmCOu0zbZLA27ogr6QzWKRgXNaoiZsYnOlyy_NsABMWgir43xNCmRkc1rhoaHbx8MWxNBr7taJTQqwGaW0sgITdGXT4wQV9WEqBxT58PxGFzmafnjtk92KqojQ7nxGODKdv6nr_x18sI6wNodpW3Yt9Lmsoka-WAOJSrMSjTQ5w',
#   'sid': '61c61dbb-6a71-4a6d-a36b-3a03fbd23220',
#   'rid': 'c3223557-4e0b-4c1e-a4cb-01c0ae4c2904',
#   'hsServerId': 'server1',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1682660961',
#    'lastUpdatedTS': '1683176030',
#    'multiplewatchlists': '1681368917',
#    'techchartpreferences': '1681796146'},
#   'ucc': 'ABCXYZ08',
#   'greetingName': 'ABC08',
#   'isTrialAccount': False,
#   'dataCenter': 'nm',
#   'searchAPIKey': 'FWOqAg9b8HofWde3k7wXgz0FTrAjKh9o'}}

# %%
inst_tokens = [{"instrument_token": "11536", "exchange_segment": "nse_cm"},
               {"instrument_token": "1594", "exchange_segment": "nse_cm"},
               {"instrument_token": "11915", "exchange_segment": "nse_cm"},
               {"instrument_token": "13245", "exchange_segment": "nse_cm"}]
# client.subscribe(instrument_tokens=inst_tokens)

# %%
a = client.quotes(instrument_tokens=inst_tokens,
              callback=on_message, quote_type="scrip_details", isIndex=False)
# Out:
# On Close Function is running!

# %%
print(a)
# Out:
# None

# %%
client.scrip_master()
# Out:
# {'filesPaths': ['https://hypersync-masterscrip-data-nonprod.s3.ap-south-1.amazonaws.com/uat-nm/2023-05-03/ncx_fo.csv',
#   'https://hypersync-masterscrip-data-nonprod.s3.ap-south-1.amazonaws.com/uat-nm/2023-05-03/nse_cm.csv',
#   'https://hypersync-masterscrip-data-nonprod.s3.ap-south-1.amazonaws.com/uat-nm/2023-05-03/bse_cm.csv',
#   'https://hypersync-masterscrip-data-nonprod.s3.ap-south-1.amazonaws.com/uat-nm/2023-05-03/nse_fo.csv',
#   'https://hypersync-masterscrip-data-nonprod.s3.ap-south-1.amazonaws.com/uat-nm/2023-05-03/cde_fo.csv',
#   'https://hypersync-masterscrip-data-nonprod.s3.ap-south-1.amazonaws.com/uat-nm/2023-05-03/mcx_fo.csv'],
#  'baseFolder': 'https://hypersync-masterscrip-data-nonprod.s3.ap-south-1.amazonaws.com/uat-nm'}

# %%
client = NeoAPI(
    access_token="eyJ4NXQiOiJNbUprWWpVMlpETmpNelpqTURBM05UZ3pObUUxTm1NNU1qTXpNR1kyWm1OaFpHUTFNakE1TmciLCJraWQiOiJaalJqTUdRek9URmhPV1EwTm1WallXWTNZemRtWkdOa1pUUmpaVEUxTlRnMFkyWTBZVEUyTlRCaVlURTRNak5tWkRVeE5qZ3pPVGM0TWpGbFkyWXpOUV9SUzI1NiIsImFsZyI6IlJTMjU2In0..aUZRtLo75BThlI3zP1El_0k5-U_dB36yaN_V_z72uTMMyLXeJt3MMDH7fN4c59kBwoPi6RwVk34Aa8jRY-qa1EmhVp9JKv78ImD1399uD2vWdKln85pa4Xenq7rYrlLv2T9x4KFPbZeg2XhO_sY1AkyKHy0oYpyTU6SDriG8p5geSwpXTSTTWe5ao9D8Sb6hKlDci5x2sB-iI2ktUQy9HBHAxHm44zDzZKRuqFqHazLcIgAL2HFERoV88h9HfTJqYPiG_rHaRuuJp35IaH773bWgacikVFZmPChH5Am98bWJsXfCj5YSIcflh9Dc9AKWpZEaIRm7x6lH_08ezqVi2w",
    environment="prod", on_message=on_message)

# %%
client.login(mobilenumber="+918793189752",password="login@123")
# Out:
# {"data":{"greetingName":"SHASHWAT","mobile":"***********52","email":"sh**************@gmail.com"}}
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..d0vG3K9ngRph_Kt7gtu40jobuCvluj9les8PxZubtFax-jiL8l7OiDgmoxYaEtckCddgj2Ty5ycS0n8E8eZx3VCNeA0BQ24cxx0B6woZWgZFC0yxA220Q8JqehtMhOMnAIgqVssykq8FGhXaEGVtdnDLKWFrO2E3prddFq7E680tE7ajOQV6FVD9rdhzAW3rHwDn0G9MWqJZ-i23SI4BkckAuHM44C9B9UswgG_fxaYWzpRioPst-ROrDtZHqqNEo1oYu5zuSY5tcF7WTOQxBUm_I58SKomIkxZ3F7doLyXghhrwyeZB7lBdKF7JM-Jd0yL-Xv0SsRWUr9R4O_mImA',
#   'sid': '6daf3b77-19c7-41f9-9041-732e7a3470aa',
#   'rid': 'e6e22fea-2859-458d-bf6a-7b1d6f1117f2',
#   'hsServerId': 'server41',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1683002170',
#    'lastUpdatedTS': '1683002170',
#    'multiplewatchlists': '1681809263'},
#   'ucc': 'YRIJ0',
#   'greetingName': 'SHASHWAT',
#   'isTrialAccount': False,
#   'dataCenter': 'nm',
#   'searchAPIKey': ''}}

# %%
client.session_2fa(OTP=input("ENTER OTP:- "))
# Out:
# ENTER OTP:- 8465
# {'data': {'token': 'eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..ERYmY1F_TO6XwTqWRuaqId8f73krJBEddp6rgAroib84SKJiP-kj2ikqAWoSKPvKDkbuWl3qUWUmVQyeRcaeGrTAcgea44FxKjkZR4t-Ebu5W3ozCuLAkNSxGLt2idXcrDJe4ATVffAG8hsprdeTuYQh2RM2-hIiZajNUKNsw-Xm9QB46jYtLCYEBxa_VV74MqywuVmPQF3G2rvNKkdwLnB7bIGg5MA-7c-Jb4IZV_7ppxJ56eFoe49eSTPN0z0vtBxaogoEcC4bnusatjCZBCV13bxCpl5vKB-s3XlTonWwWALJ7fyp8bDor3C3YFB77_w5GZlulroGYMNBYLNrKw',
#   'sid': '6daf3b77-19c7-41f9-9041-732e7a3470aa',
#   'rid': 'e6e22fea-2859-458d-bf6a-7b1d6f1117f2',
#   'hsServerId': 'server41',
#   'isUserPwdExpired': False,
#   'caches': {'baskets': '1683002170',
#    'lastUpdatedTS': '1683002170',
#    'multiplewatchlists': '1681809263'},
#   'ucc': 'YRIJ0',
#   'greetingName': 'SHASHWAT',
#   'isTrialAccount': False,
#   'dataCenter': 'nm',
#   'searchAPIKey': ''}}

# %%
a = client.search_scrip(symbol="EURINR", exchange_segment="cde_fo", expiry="26May2023", option_type="PE",
                    strike_price="855000000")

# %%
a
# Out:
# [{'pSymbol': '6530',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352685.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352685.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '855000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 200000.0,
#   'dLowPriceRange': 25000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6540',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352685.75PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352685.75PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '857500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 275000.0,
#   'dLowPriceRange': 25000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6542',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352686PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352686PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '860000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 350000.0,
#   'dLowPriceRange': 25000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6550',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352686.25PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352686.25PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '862500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 475000.0,
#   'dLowPriceRange': 25000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6552',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352686.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352686.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '865000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 625000.0,
#   'dLowPriceRange': 25000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6561',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352686.75PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352686.75PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '867500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 800000.0,
#   'dLowPriceRange': 25000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6563',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352687PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352687PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '870000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 1025000.0,
#   'dLowPriceRange': 25000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6565',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352687.25PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352687.25PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '872500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 1325000.0,
#   'dLowPriceRange': 25000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6571',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352687.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352687.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '875000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 1675000.0,
#   'dLowPriceRange': 75000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6573',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352687.75PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352687.75PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '877500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 2100000.0,
#   'dLowPriceRange': 150000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6575',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352688PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352688PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '880000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 2600000.0,
#   'dLowPriceRange': 250000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6577',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352688.25PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352688.25PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '882500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 3175000.0,
#   'dLowPriceRange': 375000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6579',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352688.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352688.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '885000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 3875000.0,
#   'dLowPriceRange': 525000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6581',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352688.75PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352688.75PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '887500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 4675000.0,
#   'dLowPriceRange': 725000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6583',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352689PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352689PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '890000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 5550000.0,
#   'dLowPriceRange': 1000000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6585',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352689.25PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352689.25PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '892500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 6575000.0,
#   'dLowPriceRange': 1325000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6587',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352689.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352689.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '895000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 7700000.0,
#   'dLowPriceRange': 1700000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6589',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352689.75PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352689.75PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '897500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 8950000.0,
#   'dLowPriceRange': 2200000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6591',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352690PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352690PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '900000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 10325000.0,
#   'dLowPriceRange': 2775000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6593',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352690.25PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352690.25PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '902500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 11825000.0,
#   'dLowPriceRange': 3475000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6595',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352690.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352690.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '905000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 13425000.0,
#   'dLowPriceRange': 4225000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6603',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352690.75PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352690.75PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '907500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 15125000.0,
#   'dLowPriceRange': 5125000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6605',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352691PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352691PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '910000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 16975000.0,
#   'dLowPriceRange': 6125000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6633',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352691.25PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352691.25PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '912500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 18900000.0,
#   'dLowPriceRange': 7250000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6642',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2352691.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2352691.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1369578600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '915000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26May2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1369551600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1369526400.0,
#   'pExerciseEndDate': 1369578600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
# ...
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 11225000.0,
#   'dLowPriceRange': 4825000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '5496',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2363090.75PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2363090.75PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1372602600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '907500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '30Jun2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1372575600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1372550400.0,
#   'pExerciseEndDate': 1372602600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 17975000.0,
#   'dLowPriceRange': 9025000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '5544',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR23SEP87PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR23SEP87PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1380205800,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '870000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26Sep2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1380178800.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1380205800.0,
#   'pExerciseEndDate': 1380205800.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 7350000.0,
#   'dLowPriceRange': 4000000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '5554',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR23SEP87.25PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR23SEP87.25PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1380205800,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '872500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26Sep2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1380178800.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1380205800.0,
#   'pExerciseEndDate': 1380205800.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 7975000.0,
#   'dLowPriceRange': 4375000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '5723',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2363091PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2363091PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1372602600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '910000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '30Jun2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1372575600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1372550400.0,
#   'pExerciseEndDate': 1372602600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 19475000.0,
#   'dLowPriceRange': 10025000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6273',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR23JUN92.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR23JUN92.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1372343400,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '925000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '27Jun2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1372316400.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1372343400.0,
#   'pExerciseEndDate': 1372343400.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 29875000.0,
#   'dLowPriceRange': 17275000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6275',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR23SEP92.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR23SEP92.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1380205800,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '925000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '26Sep2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1380178800.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1380205800.0,
#   'pExerciseEndDate': 1380205800.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 30250000.0,
#   'dLowPriceRange': 20400000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6360',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2363091.25PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2363091.25PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1372602600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '912500000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '30Jun2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1372575600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1372550400.0,
#   'pExerciseEndDate': 1372602600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 21050000.0,
#   'dLowPriceRange': 11100000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000},
#  {'pSymbol': '6362',
#   'pGroup': 'XX',
#   'pExchSeg': 'cde_fo',
#   'pInstType': 'OPTCUR',
#   'pSymbolName': 'EURINR',
#   'pTrdSymbol': 'EURINR2363091.5PE',
#   'pOptionType': 'pe',
#   'pScripRefKey': 'EURINR2363091.5PE',
#   'pISIN': None,
#   'pAssetCode': 25.0,
#   'pSubGroup': None,
#   'pCombinedSymbol': None,
#   'pDesc': None,
#   'pAmcCode': None,
#   'pContractId': None,
#   'dTickSize': 25000,
#   'lLotSize': 1,
#   'lExpiryDate': 1372602600,
#   'lMultiplier': 1000,
#   'lPrecision': 4,
#   'dStrikePrice;': '915000000.0',
#   'pExchange': 'CDS',
#   'pInstName': 'OPTCUR',
#   'pExpiryDate': '30Jun2023',
#   'pIssueDate': None,
#   'pMaturityDate': 1372575600.0,
#   'pListingDate': None,
#   'pNoDelStartDate': 0.0,
#   'pNoDelEndDate': 0.0,
#   'pBookClsStartDate': 0.0,
#   'pBookClsEndDate': 0.0,
#   'pRecordDate': 0.0,
#   'pCreditRating': '            ',
#   'pReAdminDate': 0.0,
#   'pExpulsionDate': 0.0,
#   'pLocalUpdateTime': None,
#   'pDeliveryUnits': None,
#   'pPriceUnits': None,
#   'pLastTradingDate': None,
#   'pTenderPeridEndDate': None,
#   'pTenderPeridStartDate': None,
#   'pSellVarMargin': None,
#   'pBuyVarMargin': None,
#   'pInstrumentInfo': None,
#   'pRemarksText': None,
#   'pSegment': 'CUR',
#   'pNav': None,
#   'pNavDate': None,
#   'pMfAmt': None,
#   'pSipSecurity': None,
#   'pFaceValue': None,
#   'pTrdUnits': None,
#   'pExerciseStartDate': 1372550400.0,
#   'pExerciseEndDate': 1372602600.0,
#   'pElmMargin': None,
#   'pVarMargin': None,
#   'pTotProposedLimitValue': None,
#   'pScripBasePrice': None,
#   'pSettlementType': None,
#   'pCurrectionTime': 315513000,
#   'iPermittedToTrade': 0,
#   'iBoardLotQty': 1,
#   'iMaxOrderSize': 0,
#   'iLotSize': 1,
#   'dOpenInterest': 0.0,
#   'dHighPriceRange': 22725000.0,
#   'dLowPriceRange': 12225000.0,
#   'dPriceNum': 1,
#   'dGenDen': 1,
#   'dGenNum': 1,
#   'dPriceQuatation': 0,
#   'dIssuerate': 0,
#   'dPriceDen': 1,
#   'dWarningQty': 0,
#   'dIssueCapital': 1000000000000.0,
#   'dExposureMargin': 1.25,
#   'dMinRedemptionQty': 0,
#   'lFreezeQty': 10000}]
